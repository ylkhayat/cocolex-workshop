# %%
import seaborn as sns
import matplotlib.pyplot as plt

tips = sns.load_dataset("tips")

plt.figure(figsize=(10, 6))
sns.barplot(x="day", y="total_bill", data=tips, palette="viridis")
plt.title("Total Bill by Day")
plt.show()

plt.figure(figsize=(10, 6))
sns.barplot(x="sex", y="total_bill", hue="smoker", data=tips, palette="viridis")
plt.title("Total Bill by Gender and Smoking Status")
plt.show()
# Out:
# /tmp/ipykernel_3866787/3693818338.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="day", y="total_bill", data=tips, palette="viridis")
